# %%
import pandas as pd
import numpy as np
import io
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Robert\OneDrive\Desktop\datasets\aus_final_clean.csv")
display(df.dtypes)
display(df)
# Out:
# date_of_incident                 object
# number_of_victims_under_18        int64
# number_of_victims_over_18         int64
# number_of_offenders_under_18      int64
# number_of_offenders_over_18       int64
# race_or_ethnicity_of_offender    object
# offense                          object
# offense_location                 object
# bias                             object
# dtype: object
#    date_of_incident  number_of_victims_under_18  number_of_victims_over_18  \
# 0          1/1/2017                           0                          1
# 1          2/1/2017                           0                          1
# 2         3/21/2017                           0                          0
# 3         4/12/2017                           0                          0
# 4         5/15/2017                           1                          0
# 5          6/4/2017                           0                          1
# ...

# %%
df.date_of_incident = df.date_of_incident.astype('datetime64')

# %%
df.bias = df.bias.astype('category')
bias_count = df.bias.value_counts()
bias_count
# Out:
# Anti-Black                18
# Anti-LGBT                 17
# Anti-Hispanic              7
# Anti-White                 3
# Anti-Muslim                3
# Anti-Jewish                3
# Anti-LGBT; Anti-Jewish     1
# Anti-Disability            1
# Anti-Buddhist              1
# Anti-Arab                  1
# Name: bias, dtype: int64

# %% [markdown]
# Anti-LGBT crimes attribute 32.73% of all reported hate crimes in Austin since 2017.

# %%
df.plot(subplots=True)
plt.show()
